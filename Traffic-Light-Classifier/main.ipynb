# %%
import pickle
import numpy as np
import cv2
from keras.models import Sequential
from keras.layers.core import Dense, Activation, Flatten
from keras.layers.convolutional import Convolution2D
from keras.layers.pooling import MaxPooling2D
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from keras.models import load_model

# %%
def network():
    """
    Define the network
    :return:
    """
    model = Sequential()
    model.add(Convolution2D(32, 3, 3, input_shape=(32, 32, 3)))
    model.add(MaxPooling2D((2, 2)))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(4))
    model.add(Activation('softmax'))

    return model

# %%
def train(file_path, model):

    x_, y_ = pickle.load(open(file_path, "rb"))
    random_state = 130
    X_train, x_validation, y_train, y_validation = train_test_split(x_, y_, train_size=0.80,
                                                                    test_size=0.2,
                                                                    random_state=random_state)
    # preprocess data
    X_normalized = np.array(X_train / 255.0 - 0.5) #-0.5 intensifies the normalized value around 0
    label_binarizer = LabelBinarizer()
    y_one_hot = label_binarizer.fit_transform(y_train)

    model.summary()
    model.compile('adam', 'categorical_crossentropy', ['accuracy'])
    history = model.fit(X_normalized, y_one_hot,
                        epochs=20, validation_split=0.2)

    model.save('model.h5')
    return history

# %%
def test(file_path, model):

    X_test, y_test = pickle.load(open(file_path, "rb"))

    # preprocess data
    X_normalized_test = np.array(X_test / 255.0 - 0.5)
    label_binarizer = LabelBinarizer()
    y_one_hot_test = label_binarizer.fit_transform(y_test)

    print("Testing")

    metrics = model.evaluate(X_normalized_test, y_one_hot_test)
    for metric_i in range(len(model.metrics_names)):
        metric_name = model.metrics_names[metric_i]
        metric_value = metrics[metric_i]
        print('{}: {}'.format(metric_name, metric_value))

# %%
def test_an_image(file_path, model):
    """
    resize the input image to [32, 32, 3], then feed it into the NN for prediction
    :param file_path:
    :return:
    """

    desired_dim = (32, 32)
    img = cv2.imread(file_path)
    img_resized = cv2.resize(img, desired_dim, interpolation=cv2.INTER_LINEAR)
    img_ = np.expand_dims(np.array(img_resized), axis=0)

    predicted_state = model.predict(img_)

    return predicted_state

# %%
if __name__ == "__main__":
    model = network()
    train_file = "./data/bosch_udacity_train.p"
    test_file = "./data/bosch_udacity_test.p"

    # Train the network
    train(train_file, model)

    # Test the network
    test(test_file, model=load_model('model.h5'))

    # ---Test with a single image---#
    demo_flag = True
    file_path = './data/green.jpg'
    states = ['red', 'yellow', 'green', 'off']
    if demo_flag:
        predicted_state = test_an_image(
            file_path, model=load_model('model.h5'))
        for idx in predicted_state:
            print(idx)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 10, 10, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 5, 5, 32)         0
#  )
#
#  activation (Activation)     (None, 5, 5, 32)          0
#
#  flatten (Flatten)           (None, 800)               0
#
#  dense (Dense)               (None, 4)                 3204
#
#  activation_1 (Activation)   (None, 4)                 0
#
# =================================================================
# Total params: 4,100
# Trainable params: 4,100
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 186/186 [==============================] - 3s 13ms/step - loss: 0.5401 - accuracy: 0.8245 - val_loss: 0.2743 - val_accuracy: 0.8974
# Epoch 2/20
# 186/186 [==============================] - 1s 5ms/step - loss: 0.2552 - accuracy: 0.9121 - val_loss: 0.2221 - val_accuracy: 0.9197
# Epoch 3/20
# 186/186 [==============================] - 2s 10ms/step - loss: 0.2219 - accuracy: 0.9235 - val_loss: 0.2013 - val_accuracy: 0.9312
# Epoch 4/20
# 186/186 [==============================] - 3s 14ms/step - loss: 0.2091 - accuracy: 0.9295 - val_loss: 0.1910 - val_accuracy: 0.9345
# Epoch 5/20
# 186/186 [==============================] - 2s 12ms/step - loss: 0.1989 - accuracy: 0.9340 - val_loss: 0.1931 - val_accuracy: 0.9271
# Epoch 6/20
# 186/186 [==============================] - 2s 13ms/step - loss: 0.1934 - accuracy: 0.9328 - val_loss: 0.1846 - val_accuracy: 0.9339
# Epoch 7/20
# 186/186 [==============================] - 3s 14ms/step - loss: 0.1880 - accuracy: 0.9347 - val_loss: 0.1822 - val_accuracy: 0.9352
# Epoch 8/20
# 186/186 [==============================] - 2s 13ms/step - loss: 0.1805 - accuracy: 0.9386 - val_loss: 0.1773 - val_accuracy: 0.9372
# Epoch 9/20
# 186/186 [==============================] - 2s 13ms/step - loss: 0.1796 - accuracy: 0.9399 - val_loss: 0.1783 - val_accuracy: 0.9372
# Epoch 10/20
# 186/186 [==============================] - 3s 14ms/step - loss: 0.1767 - accuracy: 0.9428 - val_loss: 0.1733 - val_accuracy: 0.9359
# Epoch 11/20
# 186/186 [==============================] - 2s 13ms/step - loss: 0.1754 - accuracy: 0.9399 - val_loss: 0.1732 - val_accuracy: 0.9352
# Epoch 12/20
# 186/186 [==============================] - 2s 12ms/step - loss: 0.1717 - accuracy: 0.9403 - val_loss: 0.1712 - val_accuracy: 0.9393
# Epoch 13/20
# 186/186 [==============================] - 2s 13ms/step - loss: 0.1696 - accuracy: 0.9428 - val_loss: 0.1688 - val_accuracy: 0.9386
# Epoch 14/20
# 186/186 [==============================] - 2s 12ms/step - loss: 0.1676 - accuracy: 0.9441 - val_loss: 0.1696 - val_accuracy: 0.9386
# Epoch 15/20
# 186/186 [==============================] - 3s 14ms/step - loss: 0.1660 - accuracy: 0.9421 - val_loss: 0.1706 - val_accuracy: 0.9359
# Epoch 16/20
# 186/186 [==============================] - 2s 11ms/step - loss: 0.1643 - accuracy: 0.9438 - val_loss: 0.1708 - val_accuracy: 0.9386
# Epoch 17/20
# 186/186 [==============================] - 2s 13ms/step - loss: 0.1620 - accuracy: 0.9431 - val_loss: 0.1725 - val_accuracy: 0.9386
# Epoch 18/20
# 186/186 [==============================] - 2s 13ms/step - loss: 0.1604 - accuracy: 0.9441 - val_loss: 0.1718 - val_accuracy: 0.9386
# Epoch 19/20
# 186/186 [==============================] - 2s 12ms/step - loss: 0.1590 - accuracy: 0.9465 - val_loss: 0.1741 - val_accuracy: 0.9386
# Epoch 20/20
# 186/186 [==============================] - 3s 14ms/step - loss: 0.1575 - accuracy: 0.9465 - val_loss: 0.1721 - val_accuracy: 0.9379
# Testing
# 33/33 [==============================] - 0s 5ms/step - loss: 0.1823 - accuracy: 0.9291
# loss: 0.18229171633720398
# accuracy: 0.9291262030601501
# 1/1 [==============================] - 0s 188ms/step
# [0. 0. 1. 0.]
